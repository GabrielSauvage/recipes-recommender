# %%
### FILTRAGE COLLABORATIF

import pandas as pd
from scipy.sparse import csr_matrix
from sklearn.neighbors import NearestNeighbors
from sklearn.decomposition import TruncatedSVD

# %%
# Charger/traiter les données
data = pd.read_csv('../data/raw/raw_recipes.csv')
data = data.drop_duplicates().dropna()
users = pd.read_csv('../data/raw/PP_users.csv')
users = users.drop_duplicates().dropna()
interactions = pd.read_csv('../data/raw/RAW_interactions.csv')
interactions = interactions.drop_duplicates().dropna()

# Filtrer les utilisateurs avec au moins 5 interactions
active_users = interactions['user_id'].value_counts()
filtered_users = active_users[active_users >= 5].index
interactions = interactions[interactions['user_id'].isin(filtered_users)]

# Filtrer les recettes avec au moins 5 interactions
popular_recipes = interactions['recipe_id'].value_counts()
filtered_recipes = popular_recipes[popular_recipes >= 5].index
interactions = interactions[interactions['recipe_id'].isin(filtered_recipes)]

# %%
# Créer un utilisateur fictif et lui attribuer des notes à 10 recettes
best_recipes = (
    interactions.groupby('recipe_id')['rating']
    .mean()
    .sort_values(ascending=False)
    .head(10)
    .index
)

new_user_id = users['u'].max() + 1  # Générer un nouvel ID
new_user_ratings = pd.DataFrame({
    'user_id': [new_user_id] * 10,
    'recipe_id': best_recipes,
    #'rating': [4, 3, 5, 2, 5, 1, 3, 4, 5, 5]
    'rating': [1, 5, 2, 5, 3, 5, 3, 2, 4, 2]
})

# Ajouter l'utilisateur fictif aux données d'interactions
interactions = pd.concat([interactions, new_user_ratings], ignore_index=True)

# Créer des mappings pour les utilisateurs et les recettes
user_mapping = {user_id: idx for idx, user_id in enumerate(interactions['user_id'].unique())}
recipe_mapping = {recipe_id: idx for idx, recipe_id in enumerate(interactions['recipe_id'].unique())}

# Mettre à jour les IDs dans les interactions
interactions['user_id'] = interactions['user_id'].map(user_mapping)
interactions['recipe_id'] = interactions['recipe_id'].map(recipe_mapping)

# Construire la matrice creuse
sparse_matrix = csr_matrix((
    interactions['rating'], 
    (interactions['user_id'], interactions['recipe_id'])
))

# Entraîner le modèle k-NN
knn_model = NearestNeighbors(metric='cosine', algorithm='brute')
knn_model.fit(sparse_matrix)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine')

# %%
def get_recommendations_knn(user_id, nResults, n_neighbors):
    user_idx = user_mapping[user_id]
    try:
        # Recherche des voisins
        distances, indices = knn_model.kneighbors(sparse_matrix[user_idx], n_neighbors=n_neighbors)
    except ValueError:
        print("Aucune donnée disponible. Utilisation des recettes les mieux notées globalement.")
        top_recipes = (
            interactions.groupby('recipe_id')['rating']
            .mean()
            .sort_values(ascending=False)
            .head(nResults)
        )
        top_recipe_ids = [key for key, value in recipe_mapping.items() if value in top_recipes.index]
        return data[data['id'].isin(top_recipe_ids)]
    
    # Identifier les utilisateurs similaires
    similar_users = [list(user_mapping.keys())[i] for i in indices.flatten()]
    similar_user_ratings = interactions[interactions['user_id'].isin(similar_users)]
    
    if similar_user_ratings.empty:
        print("Aucun utilisateur similaire trouvé. Utilisation des recettes les mieux notées globalement.")
        top_recipes = (
            interactions.groupby('recipe_id')['rating']
            .mean()
            .sort_values(ascending=False)
            .head(nResults)
        )
        top_recipe_ids = [key for key, value in recipe_mapping.items() if value in top_recipes.index]
        return data[data['id'].isin(top_recipe_ids)]
    
    # Calculer les scores des recettes basés sur les utilisateurs similaires
    top_recipes = similar_user_ratings.groupby('recipe_id')['rating'].mean().sort_values(ascending=False).head(nResults)
    top_recipe_ids = [key for key, value in recipe_mapping.items() if value in top_recipes.index]
    recommended_recipes = data[data['id'].isin(top_recipe_ids)].copy()
    
    # Calculer la fiabilité pour chaque recette
    recipe_reliability = []
    for recipe_id in top_recipes.index:
        # Récupérer les distances des voisins ayant noté cette recette
        user_ids = similar_user_ratings[similar_user_ratings['recipe_id'] == recipe_id]['user_id']
        neighbor_distances = [
            distances[0][i] for i, user in enumerate(similar_users) if user in user_ids.values
        ]
        
        # Fiabilité : inversement proportionnelle à la distance moyenne
        if neighbor_distances:
            mean_distance = sum(neighbor_distances) / len(neighbor_distances)
            reliability = 1 - mean_distance / distances.max()
        else:
            reliability = 0  # Pas de fiabilité si aucun voisin pertinent
        
        recipe_reliability.append(reliability)
    
    # Ajouter les fiabilités aux recommandations
    recommended_recipes['reliability'] = recipe_reliability
    
    return recommended_recipes

# %%
# Application de la fonction de recommandation avec k-NN
nRecipes = 1000
nNeighbors = 100
recommendations_knn = get_recommendations_knn(new_user_id, nRecipes, nNeighbors)
print("Nombre de recommandations avec knn: ", recommendations_knn.shape[0])
print(f"Recommandations pour l'utilisateur {new_user_id}:\n")
recommendations_knn.head(nRecipes)
# Out:
# Nombre de recommandations avec knn:  124
# Recommandations pour l'utilisateur 25076:
#                                                   name      id  minutes  \
# 7289                             apple sour cream cake   57771       55
# 10873                        authentic watergate salad  120800       70
# 13714                              baked cheese omelet  137324       20
# 14344                 baked ham and cheese omelet roll   28648       30
# 14540          baked macaroni with cheese and tomatoes   20147       75
# ...                                                ...     ...      ...
# 225805     whiskey marinade for chicken  pork or steak  164519       10
# 226184  white chocolate chip cranberry oatmeal cookies  112683       30
# 226962                     whole wheat english muffins   63868      145
# 228307                                   wrap up lunch   52620       15
# 229262         yes  virginia there is a great meatloaf   54257       80
#
#         contributor_id   submitted  \
# 7289             61660  2003-04-03
# 10873           170959  2005-05-06
# 13714           209747  2005-09-13
# 14344            37305  2002-05-16
# 14540            20371  2002-02-19
# ...                ...         ...
# 225805          142386  2006-04-16
# 226184           39547  2005-03-04
# 226962            3288  2003-06-05
# 228307            5060  2003-01-28
# 229262           24670  2003-02-17
#
#                                                      tags  \
# 7289    ['60-minutes-or-less', 'time-to-make', 'course...
# 10873   ['time-to-make', 'course', 'preparation', '5-i...
# 13714   ['30-minutes-or-less', 'time-to-make', 'course...
# 14344   ['ham', '30-minutes-or-less', 'time-to-make', ...
# 14540   ['weeknight', 'time-to-make', 'course', 'main-...
# ...                                                   ...
# 225805  ['15-minutes-or-less', 'time-to-make', 'course...
# 226184  ['30-minutes-or-less', 'time-to-make', 'course...
# 226962  ['weeknight', 'time-to-make', 'course', 'cuisi...
# 228307  ['15-minutes-or-less', 'time-to-make', 'course...
# 229262  ['time-to-make', 'course', 'main-ingredient', ...
#
#                                           nutrition  n_steps  \
# 7289     [275.2, 19.0, 92.0, 10.0, 7.0, 32.0, 12.0]       11
# 10873      [165.4, 13.0, 72.0, 2.0, 4.0, 20.0, 7.0]        3
# 13714    [549.0, 61.0, 9.0, 24.0, 77.0, 112.0, 2.0]        8
# 14344     [409.5, 38.0, 1.0, 25.0, 58.0, 59.0, 5.0]       11
# 14540    [304.1, 22.0, 14.0, 15.0, 31.0, 43.0, 9.0]        9
# ...                                             ...      ...
# 225805   [312.5, 20.0, 108.0, 114.0, 4.0, 9.0, 9.0]       10
# 226184       [98.6, 6.0, 34.0, 2.0, 2.0, 13.0, 4.0]        8
# 226962     [233.3, 9.0, 10.0, 5.0, 14.0, 6.0, 13.0]       10
# 228307  [297.5, 22.0, 20.0, 27.0, 18.0, 28.0, 11.0]       14
# 229262   [493.1, 43.0, 75.0, 52.0, 70.0, 55.0, 7.0]       15
#
#                                                     steps  \
# 7289    ['preheat oven to 350', 'grease a 13 x 9 x 2 b...
# 10873   ['stir pudding mix , pineapple with juice , ma...
# 13714   ['preheat oven to 400f', 'beat eggs , water , ...
# 14344   ['preheat oven to 450 degrees', 'beat eggs and...
# 14540   ['preheat oven to 350f degrees', 'cook macaron...
# ...                                                   ...
# 225805  ['place brown sugar in bowl', 'add whiskey to ...
# 226184  ['preheat oven to 375f', 'in a large bowl usin...
# 226962  ['in a large bowl , dissolve the yeast in the ...
# 228307  ['combine cream cheese , grated carrot and cum...
# 229262  ['meatloaf: combine meat loaf ingredients and ...
#
#                                               description  \
# 7289    love this cake! it is very moist, but not over...
# 10873   i checked all the other recipes here, and each...
# 13714   easy denver type omelet that is baked in the o...
# 14344   this is an easy way to serve omelets. in our h...
# 14540   i haven't made this in years, so was very plea...
# ...                                                   ...
# 225805  i used this marinade on ribeye steaks cooked o...
# 226184  i originally made these at the request of my o...
# 226962  posted in response to request. i love english ...
# 228307  entry for the ready set cook #3 contest. this ...
# 229262  absolutely delicious meatloaf and sauce! those...
#
#                                               ingredients  n_ingredients  \
# 7289    ['butter', 'sugar', 'eggs', 'vanilla', 'flour'...             13
# 10873   ['instant pistachio pudding mix', 'crushed pin...              5
# 13714   ['eggs', 'water', 'salt', 'butter', 'green oni...              8
# 14344   ['eggs', 'milk', 'all-purpose flour', 'salt', ...              7
# 14540   ['elbow macaroni', 'savory', 'white sugar', 'g...             10
# ...                                                   ...            ...
# 225805  ['whiskey', 'brown sugar', 'olive oil', 'garli...              7
# 226184  ['sugar', 'brown sugar', 'butter', 'egg', 'van...             12
# 226962  ['dry yeast', 'warm water', 'sugar', 'salt', '...              9
# 228307  ['cream cheese spread', 'carrot', 'cumin', 'wh...              9
# 229262  ['ground beef', 'bread', 'egg', 'vidalia onion...             10
#
#         reliability
# 7289       0.019258
# 10873      0.056567
# 13714      0.019258
# 14344      0.019258
# 14540      0.019258
# ...             ...
# 225805     0.013864
# 226184     0.056567
# 226962     0.056567
# 228307     0.013864
# 229262     0.024536
#
# [124 rows x 13 columns]

# %%
def filter_recommendations(tabRecommendation):
    # Séparer les valeurs de la colonne 'nutrition' en plusieurs colonnes
    nutrition_columns = ['calories', 'total fat (PDV)', 'sugar (PDV)', 'sodium (PDV)', 'protein (PDV)', 'saturated fat (PDV)', 'carbohydrates (PDV)']
    nutrition_data = tabRecommendation['nutrition'].str.strip('[]').str.split(',', expand=True)
    nutrition_data.columns = nutrition_columns

    # Ajouter les nouvelles colonnes au DataFrame original
    tabRecommendation = tabRecommendation.drop(columns=['nutrition'])
    tabRecommendation = pd.concat([tabRecommendation, nutrition_data], axis=1)

    for col in ['calories', 'total fat (PDV)', 'protein (PDV)', 'carbohydrates (PDV)']:
        tabRecommendation[col] = pd.to_numeric(tabRecommendation[col], errors='coerce')

    # Appliquer les contraintes manuellement pour ce premier exemple
    filtered_recommendations = tabRecommendation[
        (tabRecommendation['calories'] <= 700) &
        (tabRecommendation['protein (PDV)'] >= 20) &
        (tabRecommendation['total fat (PDV)'] <= 30) &
        (tabRecommendation['minutes'] <= 40)
    ]

    return filtered_recommendations;

# %%
# Filtrer les recommandations k-NN avec des contraintes
result = filter_recommendations(recommendations_knn)
print("Nombre de recommandations kNN filtrées : ", result.shape[0])
print(f"Recommandations pour l'utilisateur {new_user_id}:\n")
result.head(nRecipes)
# Out:
# Nombre de recommandations kNN filtrées :  6
# Recommandations pour l'utilisateur 25076:
#                                                 name      id  minutes  \
# 68624                           curried poached eggs   24685       10
# 102052                         hamburger helper soup   21813       40
# 118323                kittencal s tuna melt sandwich  169085       15
# 167376                               pumpkin risotto   23113       30
# 210777  thai rice noodles with chicken and asparagus  179966       40
# 212718                   the ultimate salmon fillets   53198       30
#
#         contributor_id   submitted  \
# 68624             5060  2002-04-08
# 102052           29014  2002-03-09
# 118323           89831  2006-05-22
# 167376           30716  2002-03-21
# 210777          306669  2006-07-31
# 212718           45524  2003-02-03
#
#                                                      tags  n_steps  \
# 68624   ['15-minutes-or-less', 'time-to-make', 'course...       10
# 102052  ['60-minutes-or-less', 'time-to-make', 'course...        6
# 118323  ['15-minutes-or-less', 'time-to-make', 'course...        8
# 167376  ['30-minutes-or-less', 'time-to-make', 'course...       14
# 210777  ['60-minutes-or-less', 'time-to-make', 'course...       11
# 212718  ['30-minutes-or-less', 'time-to-make', 'course...       10
#
#                                                     steps  \
# 68624   ['fill medium saucepan with about 3 inches of ...
# 102052  ['brown ground beef and onion in dutch oven un...
# 118323  ['set oven to broiler heat', 'in a bowl mix tu...
# 167376  ['heat butter and oil together in a large sauc...
# 210777  ['pour noodles into bowl and cover with very h...
# 212718  ['preheat oven to 450 degrees', 'if frozen , p...
#
#                                               description  \
# 68624   wonderful taste to start your day! from reader...
# 102052  ok - go ahead and laugh! this comforting soup ...
# 118323  trust me you will be craving this often once y...
# 167376  my ultimate comfort food. i make this so often...
# 210777  oooooooh this is good! my husband said he now ...
# 212718  living on the west coast, we have eaten a grea...
#
#                                               ingredients  n_ingredients  \
# 68624   ['ground coriander', 'curry powder', 'ground c...              8
# 102052  ['ground beef', 'onion', 'hamburger helper mix...             10
# 118323  ['solid white tuna packed in water', 'low-fat ...             11
# 167376  ['butter', 'olive oil', 'onion', 'garlic', 'mu...             12
# 210777  ['rice noodles', 'oil', 'garlic cloves', 'bone...              9
# 212718  ['salmon fillet', 'sour cream', 'prepared must...              9
#
#         reliability  calories  total fat (PDV) sugar (PDV) sodium (PDV)  \
# 68624      0.013864     389.6             23.0         7.0         46.0
# 102052     0.019258     300.6             26.0        17.0         24.0
# 118323     0.024536     304.9             17.0         6.0         25.0
# 167376     0.019258     405.6             16.0         8.0          9.0
# 210777     0.019258     435.7             15.0        17.0         45.0
# 212718     0.013864     318.3             27.0         7.0         13.0
#
#         protein (PDV) saturated fat (PDV)  carbohydrates (PDV)
# 68624            41.0                22.0                 14.0
# 102052           47.0                33.0                  3.0
# 118323           61.0                29.0                  6.0
# 167376           22.0                23.0                 21.0
# 210777           57.0                 8.0                 18.0
# 212718           66.0                27.0                  1.0

# %%
# Préparation des données pour SVD
# Réduction de dimension avec SVD
svd = TruncatedSVD(n_components=50, random_state=42)
svd_model = svd.fit_transform(sparse_matrix)  # Matrice U (représentation des utilisateurs)
svd_components = svd.components_  # Matrice V^T (représentation des recettes)

# %%
def get_recommendations_svd(user_id, nResults):
    # Trouver l'index utilisateur
    user_idx = user_mapping[user_id]
    user_ratings = svd_model[user_idx]  # Représentation de l'utilisateur dans l'espace SVD
    
    # Reformater user_ratings en 2D (1, 50) pour l'alignement des dimensions
    user_ratings = user_ratings.reshape(1, -1)
    
    # Prédictions des scores pour toutes les recettes
    predictions = user_ratings.dot(svd_components)  # dimensions alignées : (1, 50) dot (50, n_recipes)
    predictions = predictions.flatten()  # Convertir en vecteur 1D
    
    # Construire les scores pour chaque recette
    recipe_scores = pd.DataFrame({
        'recipe_id': range(len(predictions)),
        'predicted_rating': predictions
    })
    
    # Calculer la fiabilité pour chaque recette : normaliser les prédictions
    max_pred = predictions.max()
    std_pred = predictions.std()
    if std_pred > 0:  # Éviter une division par zéro
        recipe_scores['reliability'] = 1 - (abs(predictions - predictions.mean()) / std_pred)
    else:
        recipe_scores['reliability'] = 1.0  # Si pas de variance, toutes les fiabilités sont maximales
    recipe_scores['reliability'] = recipe_scores['reliability'].clip(lower=0, upper=1)  # Fiabilité entre 0 et 1
    
    # Trier les recettes par score prédictif
    top_recipes = recipe_scores.sort_values(by='predicted_rating', ascending=False).head(nResults)
    
    # Mapper les IDs des recettes
    top_recipe_ids = [key for key, value in recipe_mapping.items() if value in top_recipes['recipe_id'].values]
    recommended_recipes = data[data['id'].isin(top_recipe_ids)].copy()
    
    # Assurez-vous que toutes les recommandations ont une correspondance dans recipe_scores
    recommended_recipes = recommended_recipes.merge(
        recipe_scores[['recipe_id', 'reliability']],
        left_on='id',
        right_on='recipe_id',
        how='left'
    )
    
    # Remplir les NaN dans la colonne de fiabilité (par sécurité)
    recommended_recipes['reliability'] = recommended_recipes['reliability'].fillna(0.0)
    
    return recommended_recipes

# %%
# Application de la fonction de recommandation avec SVD
recommendations_svd = get_recommendations_svd(new_user_id, nRecipes)
print("Nombre de recommandations avec svd : ", recommendations_svd.shape[0])
print(f"Recommandations pour l'utilisateur {new_user_id}:\n")
recommendations_svd.head(nRecipes)
# Out:
# Nombre de recommandations avec svd :  987
# Recommandations pour l'utilisateur 25076:
#                                                 name      id  minutes  \
# 0    not your every day chicken salad  chicken salad  164291      245
# 1              almost  boston market creamed spinach   77206       50
# 2                           1 hour ham and bean soup   47924       55
# 3                      10 minute cheesy mexican rice  132955       10
# 4                                        24k carrots  152441       15
# ..                                               ...     ...      ...
# 982                      ziti with garlic clam sauce  323896       30
# 983                      zucchini and cucumber salad  159002       10
# 984                    zucchini and mushroom skillet  121202       35
# 985                                  zucchini gratin   15309       50
# 986                     zucchini gratin  goat cheese   93227       50
#
#      contributor_id   submitted  \
# 0            295591  2006-04-14
# 1             89831  2003-11-21
# 2             62086  2002-12-08
# 3            110078  2005-08-09
# 4            209747  2006-01-19
# ..              ...         ...
# 982          107583  2008-09-08
# 983           37449  2006-03-08
# 984           35526  2005-05-09
# 985            9869  2001-12-05
# 986           92385  2004-06-11
#
#                                                   tags  \
# 0    ['time-to-make', 'course', 'main-ingredient', ...
# 1    ['60-minutes-or-less', 'time-to-make', 'course...
# 2    ['ham', '60-minutes-or-less', 'time-to-make', ...
# 3    ['15-minutes-or-less', 'time-to-make', 'course...
# 4    ['15-minutes-or-less', 'time-to-make', 'course...
# ..                                                 ...
# 982  ['30-minutes-or-less', 'time-to-make', 'course...
# 983  ['15-minutes-or-less', 'time-to-make', 'course...
# 984  ['60-minutes-or-less', 'time-to-make', 'course...
# 985  ['60-minutes-or-less', 'time-to-make', 'course...
# 986  ['60-minutes-or-less', 'time-to-make', 'course...
#
#                                        nutrition  n_steps  \
# 0      [258.6, 20.0, 9.0, 17.0, 56.0, 16.0, 1.0]        4
# 1      [337.9, 43.0, 9.0, 24.0, 18.0, 84.0, 5.0]       14
# 2    [401.7, 18.0, 16.0, 48.0, 61.0, 12.0, 14.0]       13
# 3    [308.5, 11.0, 18.0, 55.0, 25.0, 21.0, 15.0]        7
# 4        [124.4, 9.0, 48.0, 5.0, 2.0, 18.0, 5.0]        3
# ..                                           ...      ...
# 982  [456.1, 24.0, 10.0, 31.0, 53.0, 16.0, 16.0]       13
# 983    [192.4, 24.0, 25.0, 14.0, 4.0, 11.0, 3.0]        7
# 984        [43.2, 0.0, 19.0, 0.0, 6.0, 0.0, 2.0]        5
# 985   [400.6, 46.0, 31.0, 25.0, 41.0, 88.0, 4.0]       14
# 986    [253.0, 28.0, 20.0, 9.0, 25.0, 38.0, 3.0]       15
#
#                                                  steps  \
# 0    ['blend mayonnaise , vinegar , garlic and dill...
# 1    ['in a saucepan melt butter over medium heat u...
# 2    ['heat vegetable oil in a soup pot', 'add carr...
# 3    ['mix broth and salsa in medium saucepan', 'br...
# 4    ['cook carrots until tender- or to desired don...
# ..                                                 ...
# 982  ['in large skillet , over medium heat , heat o...
# 983  ['in a large bowl , combine zucchini , cucumbe...
# 984  ['cut zucchini in half and then into 1 inch pi...
# 985  ['preheat oven to 350f degrees', 'butter 9 inc...
# 986  ['pre-heat the oven to 400 f , and coat a 1-qu...
#
#                                            description  \
# 0    a friend gave this to me  with out me ever try...
# 1    this is quite similar to the creamed spinach a...
# 2    made this one up myself, from a mix of differe...
# 3            a quick and easy recipe i got from kraft.
# 4    carrots coated with a yummy butter, brown suga...
# ..                                                 ...
# 982  a quick tasty main dish.  serve with a crusty ...
# 983  mmmmm....zucchini and cucumber marinated in an...
# 984            low carb, delicious and simple to make.
# 985                              creamy vegetable dish
# 986  this makes a tasty side dish that won't overpo...
#
#                                            ingredients  n_ingredients  \
# 0    ['light mayonnaise', 'cider vinegar', 'garlic ...              7
# 1    ['butter', 'flour', 'salt', 'half-and-half', '...             10
# 2    ['vegetable oil', 'carrot', 'celery', 'onion',...             10
# 3    ['condensed chicken broth', 'salsa', 'minute r...              4
# 4    ['carrots', 'brown sugar', 'butter', 'ground g...              4
# ..                                                 ...            ...
# 982  ['canola oil', 'onion', 'garlic cloves', 'clam...             10
# 983  ['zucchini', 'english cucumber', 'sweet onion'...             14
# 984  ['zucchini', 'fresh mushrooms', 'onion', 'oliv...              7
# 985  ['butter', 'zucchini', 'fresh tarragon', 'parm...              8
# 986  ['zucchini', 'salt', 'black pepper', 'olive oi...             11
#
#      recipe_id  reliability
# 0          NaN     0.000000
# 1          NaN     0.000000
# 2          NaN     0.000000
# 3          NaN     0.000000
# 4          NaN     0.000000
# ..         ...          ...
# 982        NaN     0.000000
# 983        NaN     0.000000
# 984        NaN     0.000000
# 985    15309.0     0.790662
# 986        NaN     0.000000
#
# [987 rows x 14 columns]

# %%
# Filtrer les recommandations SVD avec des contraintes
result = filter_recommendations(recommendations_svd)
print("Nombre de recommandations SVD filtrées : ", result.shape[0])
print(f"Recommandations pour l'utilisateur {new_user_id}:\n")
result.head(nRecipes)
# Out:
# Nombre de recommandations SVD filtrées :  51
# Recommandations pour l'utilisateur 25076:
#                                                   name      id  minutes  \
# 3                        10 minute cheesy mexican rice  132955       10
# 77                                     balsamic salmon   83719       16
# 88                                 beef noodle skillet  357999       30
# 102  beverage gang dedication shrimp  pasta  and as...  292731       30
# 104                black bean and pineapple quesadilla  261471       25
# 135  brown sugar roasted salmon with maple mustard ...  428310       30
# 193                             chickpea   olive salad  360800        7
# 194                                     chickpea salad  185331       15
# 253                 creamy corned zucchini and peppers  432934       15
# 255                    creamy dijon cheesy cauliflower   69095       30
# 268                                creole potato salad  119357       32
# 290                                   cuban bean salad  372787       10
# 299                            curried red lentil dahl  328537       35
# 303                            danish caraway potatoes  426649       15
# 333                            easy flounder au gratin  121677       25
# 339                                easy omelet for one   16193       15
# 345          egg salad sandwich   simple and delicious  160194        5
# 350                          eggplant and potato curry  432502       35
# 361                                   fast fiesta soup  132583       10
# 391                                garlic shrimp pasta  121066       30
# 434                         grilled chinese pork chops  304728       20
# 460                         herb and cheese oven fries  162983       40
# 465                                        hoisin pork   47644       40
# 490       ina garten s shrimp salad  barefoot contessa  205169       30
# 492                          indonesian sesame noodles  124567       10
# 510                  junior s white meat chicken salad  156275       30
# 536                   leftover turkey or chicken chili  105071       30
# 569                mama s supper club tilapia parmesan   53914       35
# 591                        meatless italian minestrone   38543       40
# 609                                          milk rice  134877       35
# 620                                  moo goo gai pan i   56066       25
# 634      mustard roasted salmon with lingonberry sauce  422889       25
# 643                  nat s cucumber cream cheese bagel  113853        4
# 690                            peanutty sesame noodles  112624       15
# 729                      quick hoisin chicken stir fry  162218        8
# 741                           red skin mashed potatoes  126500       40
# 771              rockin  salmon with creamy herb sauce  243431       20
# 779               salmon with dijon dill shallot sauce  295676       15
# 786                   sauted new potatoes with parsley  304533       28
# 798                                      scallop saute   25370       13
# 822                                     simmered leeks   31207       20
# 851            spaghetti with fresh tomatoes and basil  126687       28
# 852                 spaghetti with zucchini and garlic   70755       25
# 865                         spicy sugar crusted salmon  267390       15
# 877  still another tuna pasta salad        mom s tu...   28665       20
# 884                     strawberry and orange smoothie  388501        2
# 896           susan s vegas pasta    vegas baby  vegas  317368       35
# 916                        thai grilled chicken thighs   99156       25
# 943                traditional peanut butter and jelly  243965        2
# 965                    warm chickpea salad with ginger  320875       15
# 982                        ziti with garlic clam sauce  323896       30
#
#      contributor_id   submitted  \
# 3            110078  2005-08-09
# 77            54678  2004-02-12
# 88            65502  2009-02-27
# 102          233583  2008-03-19
# 104          174096  2007-10-25
# 135          526666  2010-06-02
# 193          621626  2009-03-14
# 194          199848  2006-09-08
# 253         1157312  2010-07-21
# 255           96896  2003-08-15
# 268           47510  2005-04-27
# 290          860079  2009-05-19
# 299          323186  2008-10-02
# 303          583349  2010-05-21
# 333          207176  2005-05-12
# 339            4470  2001-12-23
# 345          162888  2006-03-15
# 350          542159  2010-07-20
# 361          209747  2005-08-08
# 391           57695  2005-05-09
# 434          482933  2008-05-25
# 460           55578  2006-04-04
# 465           52282  2002-11-24
# 490          398275  2007-01-13
# 492           92385  2005-06-03
# 510           64780  2006-02-16
# 536          141293  2004-11-30
# 569           50997  2003-02-12
# 591           47559  2002-08-26
# 609           47559  2005-08-25
# 620           60231  2003-03-10
# 634          305531  2010-05-03
# 643           33443  2005-03-21
# 690          134663  2005-03-04
# 729           55221  2006-03-29
# 741           47907  2005-06-20
# 771          169969  2007-07-30
# 779          386585  2008-03-31
# 786          305531  2008-05-22
# 798           38185  2002-04-16
# 822           39547  2002-06-14
# 851          223169  2005-06-20
# 852           37449  2003-09-08
# 865          601528  2007-11-22
# 877           34146  2002-05-18
# 884          424680  2009-09-02
# 896          470351  2008-08-05
# 916          159805  2004-09-03
# 943          535512  2007-08-01
# 965          621626  2008-08-23
# 982          107583  2008-09-08
#
#                                                   tags  n_steps  \
# 3    ['15-minutes-or-less', 'time-to-make', 'course...        7
# 77   ['30-minutes-or-less', 'time-to-make', 'course...        8
# 88   ['30-minutes-or-less', 'time-to-make', 'course...       10
# 102  ['30-minutes-or-less', 'time-to-make', 'course...       13
# 104  ['30-minutes-or-less', 'time-to-make', 'course...        8
# 135  ['30-minutes-or-less', 'time-to-make', 'course...       11
# 193  ['15-minutes-or-less', 'time-to-make', 'course...        2
# 194  ['15-minutes-or-less', 'time-to-make', 'course...        3
# 253  ['15-minutes-or-less', 'time-to-make', 'course...        5
# 255  ['30-minutes-or-less', 'time-to-make', 'course...       13
# 268  ['60-minutes-or-less', 'time-to-make', 'course...        5
# 290  ['15-minutes-or-less', 'time-to-make', 'course...        8
# 299  ['60-minutes-or-less', 'time-to-make', 'course...        7
# 303  ['danish', '15-minutes-or-less', 'time-to-make...        4
# 333  ['30-minutes-or-less', 'time-to-make', 'course...        4
# 339  ['15-minutes-or-less', 'time-to-make', 'course...       11
# 345  ['15-minutes-or-less', 'time-to-make', 'course...        4
# 350  ['60-minutes-or-less', 'time-to-make', 'main-i...        8
# 361  ['15-minutes-or-less', 'time-to-make', 'course...        2
# 391  ['30-minutes-or-less', 'time-to-make', 'course...       18
# 434  ['30-minutes-or-less', 'time-to-make', 'course...       17
# 460  ['60-minutes-or-less', 'time-to-make', 'course...        5
# 465  ['60-minutes-or-less', 'time-to-make', 'course...        5
# 490  ['30-minutes-or-less', 'time-to-make', 'course...        4
# 492  ['15-minutes-or-less', 'time-to-make', 'course...        6
# 510  ['30-minutes-or-less', 'time-to-make', 'course...        9
# 536  ['30-minutes-or-less', 'time-to-make', 'course...        8
# 569  ['60-minutes-or-less', 'time-to-make', 'course...       14
# 591  ['60-minutes-or-less', 'time-to-make', 'course...        9
# 609  ['60-minutes-or-less', 'time-to-make', 'course...       10
# 620  ['30-minutes-or-less', 'time-to-make', 'course...       12
# 634  ['30-minutes-or-less', 'time-to-make', 'course...       13
# 643  ['15-minutes-or-less', 'time-to-make', 'course...        6
# 690  ['15-minutes-or-less', 'time-to-make', 'course...        3
# 729  ['15-minutes-or-less', 'time-to-make', 'course...       12
# 741  ['60-minutes-or-less', 'time-to-make', 'course...        6
# 771  ['30-minutes-or-less', 'time-to-make', 'course...       10
# 779  ['15-minutes-or-less', 'time-to-make', 'course...       12
# 786  ['30-minutes-or-less', 'time-to-make', 'course...        7
# 798  ['15-minutes-or-less', 'time-to-make', 'course...        6
# 822  ['30-minutes-or-less', 'time-to-make', 'course...       10
# 851  ['30-minutes-or-less', 'time-to-make', 'course...       10
# 852  ['30-minutes-or-less', 'time-to-make', 'course...       11
# 865  ['15-minutes-or-less', 'time-to-make', 'course...        6
# 877  ['30-minutes-or-less', 'time-to-make', 'course...        5
# 884  ['15-minutes-or-less', 'time-to-make', 'course...        2
# 896  ['60-minutes-or-less', 'time-to-make', 'course...       10
# 916  ['30-minutes-or-less', 'time-to-make', 'course...        5
# 943  ['15-minutes-or-less', 'time-to-make', 'course...        4
# 965  ['15-minutes-or-less', 'time-to-make', 'course...        7
# 982  ['30-minutes-or-less', 'time-to-make', 'course...       13
#
#                                                  steps  \
# 3    ['mix broth and salsa in medium saucepan', 'br...
# 77   ['preheat oven to 450f', 'place salmon , skin-...
# 88   ['cook noodles as directed on package', 'meanw...
# 102  ['in large skillet , heat oil and 2 tbsp butte...
# 104  ['spray pan with non-stick cooking spray', 'st...
# 135  ['preheat oven to 400f', 'combine brown sugar ...
# 193  ['mix all the ingredients together in a glass ...
# 194  ['in a large bowl , toss together the rinsed a...
# 253  ['clean and small dice zucchini , onion , and ...
# 255  ['grease a shallow baking dish', 'cook the cau...
# 268  ['cook potatoes in salted boiling water for ab...
# 290  ['mix oil , cilantro', 'lemon juice , vinegar ...
# 299  ['heat the oil in a large pan', 'cook onion an...
# 303  ['boil potatoes until tender in salted water',...
# 333  ['combine crumbs and cheese', 'mix the mayonna...
# 339  ['whip the milk and flour together', 'add sour...
# 345  ['place boiled eggs into a small bowl , mash a...
# 350  ['heat oil in a pan', 'add spices , tomatoes ,...
# 361  ['combine rotel , corn and beans in saucepan a...
# 391  ['boil pasta in water till tender , save 1 cup...
# 434  ['prepare the pork chops by removing all of th...
# 460  ['preheat oven to 500 deg', 'place sliced pota...
# 465  ['combine marinade ingredients in small bowl',...
# 490  ['in a large bowl , whisk together the mayonna...
# 492  ['in a medium bowl , combine the peanut butter...
# 510  ['to cook the chicken: fill a large saucepan h...
# 536  ['heat the oil in a large saucepan over medium...
# 569  ['preheat oven to 350 degrees', 'in buttered 1...
# 591  ['heat oil in dutch oven or stockpot', 'add ce...
# 609  ['bring water to a boil in a large saucepan', ...
# 620  ['in a bowl , combine the chicken , 1 tablespo...
# 634  ['preheat oven to 450f', 'stir 2 tablespoons m...
# 643  ['slice and toast bagel', 'spread both sides w...
# 690  ['whisk together the peanut butter , soy sauce...
# 729  ['soak snow peas in very cold water for a few ...
# 741  ['place potatoes in large pot and cover with w...
# 771  ['preheat oven to 400 degrees', 'place whole s...
# 779  ['season salmon with 1 / 4 t', 'salt and place...
# 786  ['using a vegetable peeler , remove a narrow s...
# 798  ['heat butter in 12in skillet', 'add onion , g...
# 822  ['carefully clean leeks', 'cut off the stemmy ...
# 851  ['cook spaghetti according to package directio...
# 852  ['pile up 2 or 3 layers of paper towels on a w...
# 865  ['mix together spices to create a dry rub', 'w...
# 877  ['in a large bowl , combine all ingredients', ...
# 884  ['in a blender or food processor , combine the...
# 896  ['cook pasta according to directions and drain...
# 916  ['combine all ingredients except chicken in a ...
# 943  ['spread the peanut butter on one piece of bre...
# 965  ['heat 1 tablespoon of the oil in a frying pan...
# 982  ['in large skillet , over medium heat , heat o...
#
#                                            description  \
# 3            a quick and easy recipe i got from kraft.
# 77   chatelaine - april 2001 submitted by dan mathe...
# 88   a fast meal that's tasty and easy on the budge...
# 102  this is dedicated to the beverage gang as they...
# 104  i recreated this dish from a favorite at a loc...
# 135  simple roasted salmon coated in brown sugar an...
# 193          this salad is popular in the middle east.
# 194  easy, light and healthy source of protein and ...
# 253  a really nice recipe for summer ingredients.  ...
# 255  this recipe is absolutely delicious. the dijon...
# 268  yet another delicious recipe from the pass it ...
# 290  cuban cuisine is a fusion of spanish, african ...
# 299  when i first posted this recipe, i hadn't made...
# 303  posted for zwt6, adapted from christian's dani...
# 333  don't know where i got this recipe.  found it ...
# 339  this is so easy to do and it is fail proof! th...
# 345  egg salad that is tasty and satisfying. it is ...
# 350  this is my version of a spicy dish we had on o...
# 361  found this recipe in taste of home and adjuste...
# 391  this is my hubby's specialty! this is one of t...
# 434  from chinese food site by\t lila voo.  the tim...
# 460  this is a recipe by rachael ray.  ds loves the...
# 465  i always get compliments when i serve this. ma...
# 490  take a break from the heat of the kitchen and ...
# 492  there are already numerous sesame noodles post...
# 510  whenever in nyc, i always try to cross the bri...
# 536  this is a white chili, using leftover cooked t...
# 569  you asked for it. here it is. thanks so much t...
# 591  a hearty and satisfying meal. you won't miss t...
# 609                  this is a delicious rice dessert.
# 620  haven't dusted off the old wok for a while, bu...
# 634              from epicurious.com. posted for zwt6.
# 643  this is my all time favorite breakfast! so eas...
# 690  after watching rachael ray prepare her cold se...
# 729  i love making chinese stir-fry dishes. and i l...
# 741  the addition of horseradish gives the potatoes...
# 771  this recipe went over big-time with guests tha...
# 779  a warm, tangy kick to a popular dish.    plus,...
# 786  a quick, easy, german side dish from bon appetit.
# 798  this is so easy, and very good. i just pile th...
# 822  this is my favorite way to prepare leeks. you ...
# 851  a quick, fresh summer dish. use fully ripe tom...
# 852   simple and elegant, a great way to use zucchini!
# 865      this is a simple and beautiful salmon fillet.
# 877  a tasty tuna salad which is easy to prepare. i...
# 884  this recipe (which i've slightly tweaked) come...
# 896  yes, silly name!  i ate at a little italian re...
# 916  this is my first recipe - please be kind! my k...
# 943  nothing fancy, just a classic.  either smooth ...
# 965  this moroccan salad is often served warm with ...
# 982  a quick tasty main dish.  serve with a crusty ...
#
#                                            ingredients  n_ingredients  \
# 3    ['condensed chicken broth', 'salsa', 'minute r...              4
# 77   ['salmon fillets', 'balsamic vinegar', 'liquid...              6
# 88   ['broad egg noodles', 'extra lean ground beef'...              9
# 102  ['fusilli', 'asparagus', 'shrimp', 'white wine...             12
# 104  ['flour tortilla', 'green chili', 'onion', 'pi...              7
# 135  ['salmon fillets', 'brown sugar', 'black peppe...              8
# 193  ['chickpeas', 'black olives', 'scallion', 'fre...             10
# 194  ['chickpeas', 'red onion', 'red bell pepper', ...             12
# 253  ['zucchini', 'corn', 'white onion', 'canola oi...             10
# 255  ['cauliflower', 'butter', 'all-purpose flour',...              8
# 268  ['red potatoes', 'mayonnaise', 'creole mustard...             10
# 290  ['olive oil', 'fresh cilantro', 'fresh lemon j...             16
# 299  ['olive oil', 'onion', 'garlic', 'bay leaf', '...             14
# 303  ['new potatoes', 'fresh parsley', 'fresh dill'...              5
# 333  ['flounder fillets', 'fine breadcrumbs', 'parm...              6
# 339  ['flour', 'milk', 'sour cream', 'eggs', 'salt ...             15
# 345  ['hard-boiled eggs', 'green onions', 'miracle ...              6
# 350  ['oil', 'tomatoes', 'eggplants', 'potatoes', '...             12
# 361  ['rotel', 'whole kernel corn', 'black beans', ...              6
# 391  ['medium shrimp', 'spaghetti noodles', 'garlic...             10
# 434  ['pork chops', 'hoisin sauce', 'soy sauce', 's...              7
# 460  ['potatoes', 'olive oil', 'dried italian seaso...              5
# 465  ['hoisin sauce', 'rice wine vinegar', 'soy sau...              7
# 490  ['frozen cooked shrimp', 'mayonnaise', 'dijon ...              9
# 492  ['peanut butter', 'soy sauce', 'water', 'cider...              9
# 510  ['celery leaves', 'salt', 'white pepper', 'bon...             11
# 536  ['vegetable oil', 'onion', 'garlic', 'jalapeno...             12
# 569  ['tilapia fillets', 'lemon juice', 'parmesan c...             10
# 591  ['vegetable oil', 'celery', 'onion', 'garlic',...             18
# 609  ['short-grain rice', 'water', 'milk', 'salt', ...              6
# 620  ['boneless skinless chicken breast', 'cornstar...             14
# 634  ['dijon mustard', 'unsalted butter', 'salmon f...              6
# 643  ['bagel', 'cream cheese', 'english cucumbers',...              5
# 690  ['crunchy peanut butter', 'soy sauce', 'crushe...              8
# 729  ['snow peas', 'sliced water chestnuts', 'chick...              8
# 741  ['red potatoes', 'onion powder', 'salt', 'prep...              6
# 771  ['salmon fillets', 'white wine', 'fresh ground...             11
# 779  ['salmon fillets', 'salt', 'olive oil', 'butte...             11
# 786  ['baby red potatoes', 'butter', 'italian parsl...              3
# 798  ['butter', 'onions', 'garlic', 'salt', 'pepper...              9
# 822  ['leeks', 'salt', 'fresh ground pepper', 'butt...              5
# 851  ['fresh tomato', 'onion', 'olive oil', 'sugar'...              8
# 852  ['zucchini', 'extra virgin olive oil', 'garlic...              7
# 865  ['salmon fillets', 'olive oil', 'sugar', 'chil...             10
# 877  ['tuna', 'elbow macaroni', 'hard-boiled egg', ...              8
# 884  ['orange juice', 'plain yogurt', 'strawberry y...              5
# 896  ['half-and-half', 'heavy whipping cream', 'tom...             12
# 916  ['boneless skinless chicken thighs', 'fresh ba...             10
# 943  ['sandwich bread', 'peanut butter', 'grape jel...              3
# 965  ['virgin olive oil', 'red onion', 'garlic clov...             11
# 982  ['canola oil', 'onion', 'garlic cloves', 'clam...             10
#
#      recipe_id  reliability  calories  total fat (PDV) sugar (PDV)  \
# 3          NaN     0.000000     308.5             11.0        18.0
# 77         NaN     0.000000     466.5             25.0        39.0
# 88         NaN     0.000000     303.9             11.0        23.0
# 102        NaN     0.000000     474.3             22.0        18.0
# 104        NaN     0.000000     361.6             20.0        39.0
# 135        NaN     0.000000     356.1             20.0       101.0
# 193        NaN     0.000000     430.6             20.0         3.0
# 194        NaN     0.000000     359.2             17.0        11.0
# 253        NaN     0.000000     313.9             30.0        37.0
# 255        NaN     0.000000     309.9             30.0        11.0
# 268        NaN     0.000000     328.3             18.0        20.0
# 290        NaN     0.000000     329.5             22.0        11.0
# 299        NaN     0.000000     311.3              9.0        14.0
# 303        NaN     0.000000     664.8             24.0        21.0
# 333        NaN     0.000000     429.1             25.0        11.0
# 339    16193.0     0.991248     308.4             29.0         6.0
# 345        NaN     0.000000     349.5             25.0        24.0
# 350        NaN     0.000000     364.1             12.0        65.0
# 361        NaN     0.000000     304.5              3.0        10.0
# 391        NaN     0.000000     408.1             14.0         8.0
# 434        NaN     0.000000     306.8             19.0        42.0
# 460        NaN     0.000000     448.4             29.0        10.0
# 465        NaN     0.000000     390.0             15.0        19.0
# 490        NaN     0.000000     411.7             29.0        17.0
# 492        NaN     0.000000     327.6             18.0         9.0
# 510        NaN     0.000000     317.5             25.0        10.0
# 536        NaN     0.000000     453.3             22.0        21.0
# 569        NaN     0.000000     376.8             29.0         1.0
# 591    38543.0     0.000000     350.4              6.0        47.0
# 609        NaN     0.000000     398.0             10.0        50.0
# 620        NaN     0.000000     506.9             26.0        16.0
# 634        NaN     0.000000     387.3             30.0        38.0
# 643        NaN     0.000000     387.9             17.0         3.0
# 690        NaN     0.000000     412.6             20.0        13.0
# 729        NaN     0.000000     325.3             27.0        31.0
# 741        NaN     0.000000     529.1             27.0        21.0
# 771        NaN     0.000000     389.6             23.0        40.0
# 779        NaN     0.000000     362.8             30.0         6.0
# 786        NaN     0.000000     575.2              9.0        21.0
# 798    25370.0     0.850229     412.8             27.0         2.0
# 822    31207.0     0.800505     467.9             21.0        89.0
# 851        NaN     0.000000     587.7             24.0        41.0
# 852        NaN     0.000000     556.8             23.0        18.0
# 865        NaN     0.000000     426.8             23.0        13.0
# 877    28665.0     0.224813     615.1             13.0        22.0
# 884        NaN     0.000000     477.8             11.0       158.0
# 896        NaN     0.000000     503.6             23.0        15.0
# 916        NaN     0.000000     330.2             20.0        22.0
# 943        NaN     0.000000     358.4             27.0        49.0
# 965        NaN     0.000000     424.8             29.0         7.0
# 982        NaN     0.000000     456.1             24.0        10.0
#
#     sodium (PDV)  protein (PDV) saturated fat (PDV)  carbohydrates (PDV)
# 3           55.0           25.0                21.0                 15.0
# 77          12.0          131.0                14.0                  3.0
# 88          10.0           40.0                13.0                 13.0
# 102         34.0           44.0                32.0                 17.0
# 104         44.0           33.0                35.0                 15.0
# 135         24.0           59.0                10.0                  9.0
# 193         43.0           28.0                 8.0                 21.0
# 194         30.0           22.0                 7.0                 18.0
# 253         14.0           21.0                34.0                  9.0
# 255         21.0           32.0                60.0                  6.0
# 268         30.0           22.0                12.0                 14.0
# 290         21.0           23.0                10.0                 13.0
# 299          1.0           36.0                 4.0                 15.0
# 303          6.0           28.0                49.0                 39.0
# 333         29.0           99.0                22.0                  5.0
# 339          8.0           33.0                43.0                  5.0
# 345         24.0           33.0                21.0                 10.0
# 350          1.0           20.0                 5.0                 23.0
# 361         27.0           34.0                 1.0                 19.0
# 391         20.0           41.0                25.0                 19.0
# 434         45.0           51.0                18.0                  5.0
# 460         14.0           28.0                27.0                 18.0
# 465         36.0          102.0                14.0                  7.0
# 490         94.0           84.0                13.0                  5.0
# 492         42.0           26.0                11.0                 15.0
# 510         50.0           65.0                18.0                  2.0
# 536         35.0           56.0                32.0                 18.0
# 569         17.0          101.0                53.0                  0.0
# 591         11.0           36.0                 5.0                 21.0
# 609          4.0           20.0                20.0                 24.0
# 620         22.0          118.0                13.0                  6.0
# 634         12.0           71.0                43.0                  5.0
# 643         27.0           25.0                29.0                 19.0
# 690         30.0           27.0                10.0                 20.0
# 729         25.0           50.0                20.0                  4.0
# 741          6.0           25.0                54.0                 26.0
# 771         19.0           84.0                25.0                  4.0
# 779         22.0           71.0                36.0                  1.0
# 786          3.0           27.0                19.0                 39.0
# 798         33.0          102.0                49.0                  3.0
# 822         34.0           22.0                38.0                 27.0
# 851          0.0           33.0                11.0                 31.0
# 852          0.0           31.0                11.0                 29.0
# 865         46.0          128.0                11.0                  1.0
# 877          3.0           80.0                11.0                 29.0
# 884          7.0           31.0                21.0                 30.0
# 896         16.0           42.0                22.0                 21.0
# 916         46.0           84.0                14.0                  2.0
# 943         20.0           23.0                18.0                 13.0
# 965         26.0           22.0                13.0                 17.0
# 982         31.0           53.0                16.0                 16.0

# %%
### CODE POUR LE FILTRAGE PAR CONTENU 

import pandas as pd
import string
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

recipes_df = pd.read_csv('/content/recipes/RAW_recipes.csv', on_bad_lines='skip')
recipes_df.info()
recipes_df = recipes_df.drop(
    ['description', 'submitted', 'contributor_id', 'tags', 'nutrition', 'n_steps', 'n_ingredients', 'steps'], axis=1)
recipes_df.head()
recipes_df = recipes_df.head(10000)
recipes_df = recipes_df.drop_duplicates()
recipes_df = recipes_df.dropna()

def text_cleaning(text):
    text = "".join([char for char in text if char not in string.punctuation])
    return text

recipes_df['ingredients'] = recipes_df['ingredients'].apply(lambda x: text_cleaning(x))
recipes_df.duplicated().sum()
recipes_df.isnull().sum()
tfidf = TfidfVectorizer(stop_words='english', max_features=30000)
tfidf_matrix = tfidf.fit_transform(recipes_df['ingredients'])
tfidf_matrix.shape
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)
cosine_sim
indices = pd.Series(recipes_df.index, index=recipes_df['name']).drop_duplicates()
indices

def get_recommendations(title, cosine_sim=cosine_sim):
    idx = indices[title]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the scores of the 5 most similar food
    sim_scores = sim_scores[1:6]

    food_indices = [i[0] for i in sim_scores]

    df_reco = pd.DataFrame(recipes_df['name'].iloc[food_indices])
    df_reco['ingredients'] = recipes_df['ingredients'].iloc[food_indices]
    return df_reco

print(get_recommendations('asparagus with mustard dill sauce'))
