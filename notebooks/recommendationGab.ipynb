# %%
import pandas as pd
from scipy.sparse import csr_matrix
from sklearn.neighbors import NearestNeighbors
from sklearn.decomposition import TruncatedSVD

# %%
# Charger/traiter les données
data = pd.read_csv('../data/raw/raw_recipes.csv')
data = data.drop_duplicates().dropna()
users = pd.read_csv('../data/raw/PP_users.csv')
users = users.drop_duplicates().dropna()
interactions = pd.read_csv('../data/raw/RAW_interactions.csv')
interactions = interactions.drop_duplicates().dropna()

# Garder uniquement les recettes notées
noted_recipe_ids = interactions['recipe_id'].unique()
data = data[data['id'].isin(noted_recipe_ids)]

# %%
# Créer un utilisateur fictif et lui attribuer des notes à 10 recettes
best_recipes = (
    interactions.groupby('recipe_id')['rating']
    .mean()
    .sort_values(ascending=False)
    .head(10)
    .index
)

new_user_id = users['u'].max() + 1  # Générer un nouvel ID
new_user_ratings = pd.DataFrame({
    'user_id': [new_user_id] * 10,
    'recipe_id': best_recipes,
    'rating': [4, 3, 5, 2, 5, 1, 3, 4, 5, 5]
    #'rating': [1, 5, 2, 5, 3, 5, 3, 2, 4, 2]
})

# Ajouter l'utilisateur fictif aux données d'interactions
interactions = pd.concat([interactions, new_user_ratings], ignore_index=True)

# Créer des mappings pour les utilisateurs et les recettes
user_mapping = {user_id: idx for idx, user_id in enumerate(interactions['user_id'].unique())}
recipe_mapping = {recipe_id: idx for idx, recipe_id in enumerate(interactions['recipe_id'].unique())}

# Mettre à jour les IDs dans les interactions
interactions['user_id'] = interactions['user_id'].map(user_mapping)
interactions['recipe_id'] = interactions['recipe_id'].map(recipe_mapping)

# Construire la matrice creuse
sparse_matrix = csr_matrix((
    interactions['rating'], 
    (interactions['user_id'], interactions['recipe_id'])
))

# Entraîner le modèle k-NN
knn_model = NearestNeighbors(metric='cosine', algorithm='brute')
knn_model.fit(sparse_matrix)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine')

# %%
# Fonction pour obtenir des recommandations avec k-NN
def get_recommendations(user_id, nResults, n_neighbors):
    user_idx = user_mapping[user_id]
    try:
        distances, indices = knn_model.kneighbors(sparse_matrix[user_idx], n_neighbors=n_neighbors)
    except ValueError:
        print("Aucune données disponible. Utilisation des recettes les mieux notées globalement.")
        top_recipes = (
            interactions.groupby('recipe_id')['rating']
            .mean()
            .sort_values(ascending=False)
            .head(nResults)
        )
        top_recipe_ids = [key for key, value in recipe_mapping.items() if value in top_recipes.index]
        return data[data['id'].isin(top_recipe_ids)]
    
    similar_users = [list(user_mapping.keys())[i] for i in indices.flatten()]
    similar_user_ratings = interactions[interactions['user_id'].isin(similar_users)]
    
    if similar_user_ratings.empty:
        print("Aucun utilisateur similaire trouvé. Utilisation des recettes les mieux notées globalement.")
        top_recipes = (
            interactions.groupby('recipe_id')['rating']
            .mean()
            .sort_values(ascending=False)
            .head(nResults)
        )
        top_recipe_ids = [key for key, value in recipe_mapping.items() if value in top_recipes.index]
        return data[data['id'].isin(top_recipe_ids)]
    
    top_recipes = similar_user_ratings.groupby('recipe_id')['rating'].mean().sort_values(ascending=False).head(nResults)
    top_recipe_ids = [key for key, value in recipe_mapping.items() if value in top_recipes.index]
    recommended_recipes = data[data['id'].isin(top_recipe_ids)]
    return recommended_recipes

# %%
# Application de la fonction de recommandation avec k-NN
nRecipes = 1000
nNeighbors = 100
recommendations_knn = get_recommendations(new_user_id, nRecipes, nNeighbors)
print("Nombre de recommandations avec knn: ", recommendations_knn.shape[0])
print(f"Recommandations pour l'utilisateur {new_user_id}:\n")
recommendations_knn.head(nRecipes)
# Out:
# Nombre de recommandations avec knn:  166
# Recommandations pour l'utilisateur 25076:
#                                                      name      id  minutes  \
# 122                                100 broccoli casserole  116679       50
# 2546    addictive chicken tenders  one taste and you r...   69990       50
# 3975                                almond anise biscotti   78048       60
# 4182                                           aloo matar  220883       40
# 4381                                 amanda s thai peanut  175230       25
# ...                                                   ...     ...      ...
# 222239             vegetarian pho  vietnamese noodle soup  201382       40
# 225975                    white bean zucchini basil salad  125580       20
# 227203  whoopie pies   the real deal   lancaster co  r...   54787       38
# 228032                wonderful curried sweet potato soup  161324       30
# 231179                    zucchini garlic chicken skillet   13981       40
#
#         contributor_id   submitted  \
# 122             107334  2005-04-12
# 2546             48263  2003-08-28
# 3975             49879  2003-12-06
# 4182            450571  2007-04-05
# 4381            236462  2006-06-28
# ...                ...         ...
# 222239          334301  2006-12-21
# 225975           16975  2005-06-11
# 227203           41706  2003-02-24
# 228032          225021  2006-03-24
# 231179           21752  2001-11-08
#
#                                                      tags  \
# 122     ['60-minutes-or-less', 'time-to-make', 'course...
# 2546    ['60-minutes-or-less', 'time-to-make', 'course...
# 3975    ['60-minutes-or-less', 'time-to-make', 'course...
# 4182    ['60-minutes-or-less', 'time-to-make', 'course...
# 4381    ['30-minutes-or-less', 'time-to-make', 'course...
# ...                                                   ...
# 222239  ['60-minutes-or-less', 'time-to-make', 'course...
# 225975  ['30-minutes-or-less', 'time-to-make', 'course...
# 227203  ['60-minutes-or-less', 'time-to-make', 'course...
# 228032  ['30-minutes-or-less', 'time-to-make', 'course...
# 231179  ['60-minutes-or-less', 'time-to-make', 'course...
#
#                                           nutrition  n_steps  \
# 122      [212.0, 25.0, 11.0, 19.0, 11.0, 50.0, 4.0]        5
# 2546      [450.4, 51.0, 2.0, 54.0, 69.0, 98.0, 1.0]        6
# 3975        [138.9, 9.0, 42.0, 3.0, 5.0, 13.0, 6.0]       17
# 4182       [184.3, 14.0, 22.0, 11.0, 9.0, 6.0, 7.0]       10
# 4381    [480.6, 22.0, 54.0, 54.0, 42.0, 13.0, 23.0]       12
# ...                                             ...      ...
# 222239       [304.3, 0.0, 9.0, 5.0, 7.0, 0.0, 23.0]       22
# 225975      [139.5, 9.0, 6.0, 10.0, 12.0, 4.0, 5.0]        8
# 227203   [518.7, 46.0, 169.0, 9.0, 8.0, 32.0, 19.0]       14
# 228032  [283.8, 13.0, 45.0, 16.0, 16.0, 12.0, 13.0]       16
# 231179    [490.3, 17.0, 64.0, 7.0, 70.0, 9.0, 21.0]        5
#
#                                                     steps  \
# 122     ['cook broccoli until tender in the amount of ...
# 2546    ['preheat oven to 350', 'combine all dry ingre...
# 3975    ['cream butter and 1 cup sugar', 'add eggs one...
# 4182    ['heat oil over medium heat', 'add cumin seed ...
# 4381    ['in a large pot , cook fettucini as directed'...
# ...                                                   ...
# 222239  ['tear greens into bite-sized pieces', 'use bo...
# 225975  ['rinse beans in colander and place in a large...
# 227203  ['cream shortening , sugar and eggs', 'add van...
# 228032  ['soup:', 'in a soup pot , heat oil over mediu...
# 231179  ['toss chicken , onions and garlic with the ol...
#
#                                               description  \
# 122     this is a nice change of pace from the cheez w...
# 2546    i found this recipe on a low-carb site, (dh is...
# 3975                    one of my most requested recipes.
# 4182    this is a recipe for aloo matar that i got off...
# 4381    by far the best and healthiest thai peanut i'v...
# ...                                                   ...
# 222239  from sally bernstien's article on vietnamese f...
# 225975  a delicious summer salad perfect for picnics a...
# 227203  mmmmmmmmmmmmmmmmm! if you've never had a whoop...
# 228032  this is a wonderful soup. and look at the list...
# 231179  a very quick and easy dish for a middle-of-the...
#
#                                               ingredients  n_ingredients
# 122     ['frozen broccoli', 'cream cheese', 'dry onion...              7
# 2546    ['chicken tenders', 'parmesan cheese', 'dried ...              8
# 3975    ['butter', 'sugar', 'eggs', 'almond extract', ...             10
# 4182    ['potatoes', 'frozen peas', 'green chili', 'wh...             14
# 4381    ['fettuccine', 'broccoli', 'carrot', 'garlic',...             10
# ...                                                   ...            ...
# 222239  ['rice noodles', 'seitan', 'bean sprouts', 'na...             21
# 225975  ['zucchini', 'roma tomatoes', 'great northern ...             11
# 227203  ['oil', 'brown sugar', 'eggs', 'flour', 'salt'...             12
# 228032  ['oil', 'onion', 'garlic clove', 'curry paste'...             12
# 231179  ['boneless skinless chicken breast halves', 'o...              8
#
# [166 rows x 12 columns]

# %%
def filter_recommendations(tabRecommendation):
    # Séparer les valeurs de la colonne 'nutrition' en plusieurs colonnes
    nutrition_columns = ['calories', 'total fat (PDV)', 'sugar (PDV)', 'sodium (PDV)', 'protein (PDV)', 'saturated fat (PDV)', 'carbohydrates (PDV)']
    nutrition_data = tabRecommendation['nutrition'].str.strip('[]').str.split(',', expand=True)
    nutrition_data.columns = nutrition_columns

    # Ajouter les nouvelles colonnes au DataFrame original
    tabRecommendation = tabRecommendation.drop(columns=['nutrition'])
    tabRecommendation = pd.concat([tabRecommendation, nutrition_data], axis=1)

    for col in ['calories', 'total fat (PDV)', 'protein (PDV)', 'carbohydrates (PDV)']:
        tabRecommendation[col] = pd.to_numeric(tabRecommendation[col], errors='coerce')

    # Appliquer les contraintes manuellement pour ce premier exemple
    filtered_recommendations = tabRecommendation[
        (tabRecommendation['calories'] >= 300) &
        (tabRecommendation['calories'] <= 700) &
        (tabRecommendation['protein (PDV)'] >= 20) &
        (tabRecommendation['total fat (PDV)'] <= 30) &
        (tabRecommendation['minutes'] <= 40)
    ]

    return filtered_recommendations;

# %%
# Filtrer les recommandations k-NN avec des contraintes
result = filter_recommendations(recommendations_knn)
print("Nombre de recommandations kNN filtrées : ", result.shape[0])
print(f"Recommandations pour l'utilisateur {new_user_id}:\n")
result.head(nRecipes)
# Out:
# Nombre de recommandations kNN filtrées :  14
# Recommandations pour l'utilisateur 25076:
#                                                      name      id  minutes  \
# 4381                                 amanda s thai peanut  175230       25
# 20793                                       beef taquitos  217324       30
# 26917                        boneless hoisin country ribs  313039       25
# 79857       egyptian red snapper in red pepper mint sauce  133946       20
# 85488        fontina topped chicken cutlets with couscous  129527       35
# 100567  ground turkey with creamy squash sauce  over n...  192361       30
# 133847                                 mexicali casserole   16328       40
# 148006                           one pot spaghetti supper  413237       25
# 150647                        oven baked chicken parmesan   42972       40
# 181994         savory rice pilaf with lavender   apricots   66672       35
# 208261     tandoori chicken burgers with minted cucumbers  121580       34
# 210504             thai coconut rice noodles with chicken  304140       40
# 211021        thai style tilapia with coconut curry broth  217245       27
# 231179                    zucchini garlic chicken skillet   13981       40
#
#         contributor_id   submitted  \
# 4381            236462  2006-06-28
# 20793           141293  2007-03-18
# 26917            37722  2008-07-09
# 79857           183964  2005-08-18
# 85488           185293  2005-07-12
# 100567           58104  2006-10-26
# 133847           27371  2001-12-28
# 148006          316094  2010-02-16
# 150647           53510  2002-10-14
# 181994           92700  2003-07-14
# 208261          119466  2005-05-11
# 210504           37636  2008-05-18
# 211021          398275  2007-03-17
# 231179           21752  2001-11-08
#
#                                                      tags  n_steps  \
# 4381    ['30-minutes-or-less', 'time-to-make', 'course...       12
# 20793   ['30-minutes-or-less', 'time-to-make', 'course...       13
# 26917   ['30-minutes-or-less', 'time-to-make', 'course...        8
# 79857   ['30-minutes-or-less', 'time-to-make', 'course...        4
# 85488   ['60-minutes-or-less', 'time-to-make', 'course...       17
# 100567  ['curries', '30-minutes-or-less', 'time-to-mak...        9
# 133847  ['60-minutes-or-less', 'time-to-make', 'course...       11
# 148006  ['30-minutes-or-less', 'time-to-make', 'main-i...        9
# 150647  ['60-minutes-or-less', 'time-to-make', 'main-i...        7
# 181994  ['60-minutes-or-less', 'time-to-make', 'course...       13
# 208261  ['60-minutes-or-less', 'time-to-make', 'course...        9
# 210504  ['60-minutes-or-less', 'time-to-make', 'course...       14
# 211021  ['30-minutes-or-less', 'time-to-make', 'course...       11
# 231179  ['60-minutes-or-less', 'time-to-make', 'course...        5
#
#                                                     steps  \
# 4381    ['in a large pot , cook fettucini as directed'...
# 20793   ['heat the oven to 400', 'heat the oil in a la...
# 26917   ['preheat oven to 400 degrees f', 'line a larg...
# 79857   ['saute onion in olive oil until golden', 'add...
# 85488   ['heat oven to 375f', 'in large nonstick skill...
# 100567  ['heat oil in a large pan', 'add onions and ga...
# 133847  ['start browning meat in a large skillet addin...
# 148006  ['cook the pasta following package directions'...
# 150647  ['preheat oven to 400 degrees', 'dip chicken i...
# 181994  ['melt butter in medium saucepan', 'gradually ...
# 208261  ['cucumbers:', 'in a small bowl , combine cucu...
# 210504  ['heat water for noodles and cook pasta 6-8 mi...
# 211021  ['in a large saute pan , heat the oil over mod...
# 231179  ['toss chicken , onions and garlic with the ol...
#
#                                               description  \
# 4381    by far the best and healthiest thai peanut i'v...
# 20793   like tacos, only neater to eat. in mexico, the...
# 26917   a very nice combination of flavors for a quint...
# 79857   this recipe is posted for the zaar world tour ...
# 85488   this is so easy and very good!!  people think ...
# 100567  low fat made with a puree of winter squash be ...
# 133847  i like this recipe because it is not only low-...
# 148006  this recipe was featured in the 1-2-3 eats col...
# 150647               an easy recipe for chicken parmesan!
# 181994  i got this recipe from the herb gardeners at f...
# 208261  a quick and different burger from midwest living.
# 210504  if you like pad thai you will love this. if yo...
# 211021  courtesy of ellie krieger.  please note the or...
# 231179  a very quick and easy dish for a middle-of-the...
#
#                                               ingredients  n_ingredients  \
# 4381    ['fettuccine', 'broccoli', 'carrot', 'garlic',...             10
# 20793   ['vegetable oil', 'onion', 'garlic clove', 'le...             11
# 26917   ['garlic cloves', 'hoisin sauce', 'brown sugar...              7
# 79857   ['red snapper fillets', 'olive oil', 'red onio...              9
# 85488   ['olive oil', 'garlic clove', 'baby spinach', ...              9
# 100567  ['oil', 'garlic cloves', 'onion', 'ground turk...             17
# 133847  ['ground turkey', 'fat free cheese', 'onion', ...             10
# 148006  ['spaghetti', 'olive oil', 'onion', 'pasta sau...              9
# 150647  ['boneless skinless chicken breast halves', 'e...              5
# 181994  ['butter', 'onion', 'celery', 'garlic clove', ...             15
# 208261  ['cucumber', 'red onion', 'of fresh mint', 'ba...             12
# 210504  ['rice vermicelli', 'peanut oil', 'boneless sk...             20
# 211021  ['vegetable oil', 'shallots', 'red curry paste...             13
# 231179  ['boneless skinless chicken breast halves', 'o...              8
#
#         calories  total fat (PDV) sugar (PDV) sodium (PDV)  protein (PDV)  \
# 4381       480.6             22.0        54.0         54.0           42.0
# 20793      471.4             30.0        13.0         43.0           48.0
# 26917      427.3             16.0       143.0         68.0           76.0
# 79857      328.6              9.0         7.0          5.0          120.0
# 85488      637.0             30.0         4.0         83.0          103.0
# 100567     387.7             15.0        18.0          9.0           49.0
# 133847     443.4             17.0        71.0         80.0           69.0
# 148006     366.1             13.0        34.0         24.0           35.0
# 150647     484.1             25.0        74.0         52.0           77.0
# 181994     460.7             29.0        70.0         47.0           23.0
# 208261     301.5              9.0        19.0         26.0           60.0
# 210504     419.3             19.0        19.0         22.0           35.0
# 211021     339.3             10.0         2.0         24.0           81.0
# 231179     490.3             17.0        64.0          7.0           70.0
#
#        saturated fat (PDV)  carbohydrates (PDV)
# 4381                  13.0                 23.0
# 20793                 35.0                 15.0
# 26917                 18.0                 14.0
# 79857                  5.0                  1.0
# 85488                 46.0                 20.0
# 100567                13.0                 16.0
# 133847                17.0                 18.0
# 148006                 7.0                 17.0
# 150647                31.0                 13.0
# 181994                32.0                 21.0
# 208261                 8.0                  9.0
# 210504                24.0                 19.0
# 211021                 8.0                 10.0
# 231179                 9.0                 21.0

# %%
# Préparation des données pour SVD
# Réduction de dimension avec SVD
svd = TruncatedSVD(n_components=50, random_state=42)
matrix_svd = svd.fit_transform(sparse_matrix)

# %%
# Function to get recommendations with SVD
def get_svd_recommendations(user_id, nResults):
    user_idx = user_mapping[user_id]
    user_vector = matrix_svd[user_idx]
    scores = matrix_svd.dot(user_vector)
    top_indices = scores.argsort()[-nResults:][::-1]
    
    # Handle missing keys gracefully
    top_recipe_ids = [recipe_mapping.get(i, None) for i in top_indices if i in recipe_mapping]
    top_recipe_ids = [id for id in top_recipe_ids if id is not None]
    
    return data[data['id'].isin(top_recipe_ids)]

# %%
# Application de la fonction de recommandation avec SVD
recommendations_svd = get_svd_recommendations(new_user_id, nRecipes)
print("Nombre de recommandations avec svd : ", recommendations_svd.shape[0])
print(f"Recommandations pour l'utilisateur {new_user_id}:\n")
recommendations_svd.head(nRecipes)
# Out:
# Nombre de recommandations avec svd :  241
# Recommandations pour l'utilisateur 25076:
#                                                      name      id  minutes  \
# 487     old reliable  french bread  for kitchen aid mi...   52289      170
# 559                             three cheese  cheese ball   77380      375
# 1101                      2   baby potatoes with rosemary  162657       60
# 1608                                        5 spice sugar  101898        5
# 1807                                   8 vegetable ragout  136399       30
# ...                                                   ...     ...      ...
# 227678                                         wine punch   95943        5
# 228298                                     wounded dragon   16047        5
# 229249  yemiser selatta   ethiopian lentil salad with ...  133099       70
# 230492              zesty italian peasant bread appetizer   95069       22
# 230840                      zsidotojas  hungarian egg dip  200338       25
#
#         contributor_id   submitted  \
# 487              39949  2003-01-27
# 559              37636  2003-11-26
# 1101            210188  2006-04-03
# 1608            128047  2004-10-13
# 1807            235262  2005-09-06
# ...                ...         ...
# 227678          147217  2004-07-20
# 228298           10649  2001-12-20
# 229249           27678  2005-08-10
# 230492           61121  2004-07-05
# 230840          388615  2006-12-12
#
#                                                      tags  \
# 487     ['weeknight', 'time-to-make', 'course', 'main-...
# 559     ['weeknight', 'time-to-make', 'course', 'main-...
# 1101    ['lactose', '60-minutes-or-less', 'time-to-mak...
# 1608    ['lactose', '15-minutes-or-less', 'time-to-mak...
# 1807    ['30-minutes-or-less', 'time-to-make', 'course...
# ...                                                   ...
# 227678  ['15-minutes-or-less', 'time-to-make', 'course...
# 228298  ['15-minutes-or-less', 'time-to-make', 'course...
# 229249  ['time-to-make', 'course', 'main-ingredient', ...
# 230492  ['30-minutes-or-less', 'time-to-make', 'course...
# 230840  ['30-minutes-or-less', 'time-to-make', 'course...
#
#                                               nutrition  n_steps  \
# 487              [113.5, 1.0, 0.0, 10.0, 6.0, 0.0, 7.0]       18
# 559     [1846.7, 243.0, 26.0, 130.0, 173.0, 436.0, 9.0]        5
# 1101           [207.3, 8.0, 10.0, 15.0, 7.0, 4.0, 11.0]        6
# 1608              [52.3, 0.0, 50.0, 0.0, 0.0, 0.0, 4.0]        2
# 1807           [156.2, 6.0, 36.0, 27.0, 10.0, 3.0, 9.0]        6
# ...                                                 ...      ...
# 227678            [55.2, 0.0, 33.0, 0.0, 0.0, 0.0, 3.0]        3
# 228298            [58.2, 0.0, 25.0, 0.0, 0.0, 0.0, 3.0]        3
# 229249        [309.7, 11.0, 9.0, 24.0, 33.0, 4.0, 14.0]        7
# 230492             [79.8, 4.0, 1.0, 7.0, 5.0, 5.0, 3.0]        9
# 230840        [277.7, 37.0, 8.0, 32.0, 20.0, 61.0, 1.0]        3
#
#                                                     steps  \
# 487     ['dissolve yeast in warm water in warmed mixer...
# 559     ['mix all ingredients thoroughly', 'divide mix...
# 1101    ['preheat oven to 425f', 'cut each potato in h...
# 1608    ['for a gift: layer in a 1 / 3-1 / 2 c clear ,...
# 1807    ['saute onion , carrot , garlic in vegetable f...
# ...                                                   ...
# 227678  ['combine all ingredients in a punch bowl', 'a...
# 228298  ['layer in the order given above into a shot g...
# 229249  ['place the lentils in a sieve and wash them u...
# 230492  ['preheat oven to 400 degrees f', 'place bread...
# 230840  ['peel and mash eggs', 'add rest of the ingred...
#
#                                               description  \
# 487     this recipe came with my kitchen aid mixer, an...
# 559     great for parties and superbowl get-togethers....
# 1101    this is the starch for the easter dinner from ...
# 1608    found this in sunset magazine around christmas...
# 1807    a wonderful vegetable dish for everyday or com...
# ...                                                   ...
# 227678                                   good party punch
# 228298  this is a fantastic name for a drink. i love t...
# 229249  this is traditionally served during lent eithe...
# 230492  this came from the bhg website. quick, easy an...
# 230840  this dip can be used as a sandwich filling, or...
#
#                                               ingredients  n_ingredients
# 487     ['active dry yeast', 'water', 'salt', 'margari...              7
# 559     ['cream cheese', 'cheddar cheese', 'milk', 'bl...              8
# 1101    ['small potatoes', 'olive oil', 'fresh rosemar...              6
# 1608    ['sugar', 'ground cinnamon', 'ground nutmeg', ...              6
# 1807    ['onion', 'carrot', 'minced garlic cloves', 'v...             12
# ...                                                   ...            ...
# 227678  ['rose wine', '7-up soda', 'orange juice conce...              4
# 228298  ['grenadine', 'bacardi 151 rum', 'midori melon...              3
# 229249  ['dried lentils', 'red wine vinegar', 'vegetab...              7
# 230492  ['italian bread', 'olive oil', 'garlic clove',...              7
# 230840  ['hard-boiled eggs', 'onion', 'butter', 'dijon...              5
#
# [241 rows x 12 columns]

# %%
# Filtrer les recommandations SVD avec des contraintes
result = filter_recommendations(recommendations_svd)
print("Nombre de recommandations SVD filtrées : ", result.shape[0])
print(f"Recommandations pour l'utilisateur {new_user_id}:\n")
result.head(nRecipes)
# Out:
# Nombre de recommandations SVD filtrées :  15
# Recommandations pour l'utilisateur 25076:
#                                                  name      id  minutes  \
# 28307          breaded garlic and dill fish   low fat   82678       35
# 42597                     chicken and broccoli mornay   99372       30
# 43342        chicken breast with portabella mushrooms   92571       40
# 77167                  easy microwave pouring custard  133138        7
# 87637                            fried egg sandwiches   43027       40
# 96287                           greek chicken breasts   84147       35
# 111029                   indian lentils and rice soup   22749       30
# 115527  jolean s k sandwiches  exceptional tuna melts  121324       25
# 160579                       pineapple sesame chicken  207762       35
# 163101                        pork chops in soy sauce  105484       40
# 169432                quick tuna and clam pappardelle   75199       30
# 169559                          quickest pasta supper   32982        6
# 185435                   shrimp and crab egg foo yong   59262       30
# 194375    speedy scallops with corn and sweet peppers  169951       25
# 215200                 tomato  basil  and lentil soup  200421       40
#
#         contributor_id   submitted  \
# 28307            41409  2004-01-31
# 42597           158304  2004-09-07
# 43342           142004  2004-06-03
# 77167            11297  2005-08-10
# 87637            37779  2002-10-14
# 96287            87877  2004-02-16
# 111029            3288  2002-03-16
# 115527          185105  2005-05-09
# 160579          378710  2007-01-26
# 163101          178271  2004-12-06
# 169432           68460  2003-11-03
# 169559           46534  2002-07-02
# 185435           49304  2003-04-12
# 194375          270514  2006-05-26
# 215200          299608  2006-12-13
#
#                                                      tags  n_steps  \
# 28307   ['60-minutes-or-less', 'time-to-make', 'course...       11
# 42597   ['30-minutes-or-less', 'time-to-make', 'course...        5
# 43342   ['60-minutes-or-less', 'time-to-make', 'course...       16
# 77167   ['15-minutes-or-less', 'time-to-make', 'course...        5
# 87637   ['bacon', '60-minutes-or-less', 'time-to-make'...       12
# 96287   ['60-minutes-or-less', 'time-to-make', 'course...       11
# 111029  ['30-minutes-or-less', 'time-to-make', 'course...        8
# 115527  ['30-minutes-or-less', 'time-to-make', 'course...        7
# 160579  ['60-minutes-or-less', 'time-to-make', 'course...       13
# 163101  ['60-minutes-or-less', 'time-to-make', 'course...        3
# 169432  ['30-minutes-or-less', 'time-to-make', 'course...       11
# 169559  ['15-minutes-or-less', 'time-to-make', 'course...        5
# 185435  ['30-minutes-or-less', 'time-to-make', 'course...        7
# 194375  ['30-minutes-or-less', 'time-to-make', 'course...       12
# 215200  ['60-minutes-or-less', 'time-to-make', 'course...       10
#
#                                                     steps  \
# 28307   ['toast the panko bread crumbs on an unoiled b...
# 42597   ['for sauce , combine first 4 ingredients in s...
# 43342   ['remove any unwanted fat from chicken', 'mix ...
# 77167   ['in a microwave safe jug heat the milk on med...
# 87637   ['spread one side of each slice of toast with ...
# 96287   ['combine flour , salt , pepper , and oregano ...
# 111029  ['spray 3-quart saucepan with nonstick cooking...
# 115527  ['preheat oven to 325 degrees', 'mix all ingre...
# 160579  ['cut chicken into bitesize chucks', 'drain pi...
# 163101  ['season pork chops with salt , pepper , and g...
# 169432  ['heat a large pot of water to a boil', 'combi...
# 169559  ['cook the pasta according to the packet instr...
# 185435  ['in a large bowl , mix in salt and pepper int...
# 194375  ['pre-heat skillet with 1 tbs butter over medi...
# 215200  ['in a large soup pot , saute the onions on me...
#
#                                               description  \
# 28307   this is a wonderful, healthy dish that's reall...
# 42597   chicken, broccoli, and a cheesy gravy. who can...
# 43342   i got tired of the typical chicken dinners, so...
# 77167   **please note this was made in a 700wt microwa...
# 87637   this is something my grandmother used to make ...
# 96287   this is another recipe i have had for years an...
# 111029  from start to finish, you can have lentil soup...
# 115527  don't know why my mom called these k-sandwiche...
# 160579  this is a very easy dish to make in one skille...
# 163101  it's a recipe my mom always made growing up, a...
# 169432  this is such a cool recipe! it's like a tuna n...
# 169559  this is the quickest, simplest most delicious ...
# 185435  this is a very simple dish similar to making a...
# 194375  i've been working on this recipe for awhile to...
# 215200  i created this soup many years ago after eatin...
#
#                                               ingredients  n_ingredients  \
# 28307   ['white fish fillets', 'panko breadcrumbs', 't...              9
# 42597   ['chicken gravy', 'swiss cheese', 'parmesan ch...              7
# 43342   ['boneless skinless chicken breast halves', 's...              9
# 77167                      ['milk', 'egg yolks', 'sugar']              3
# 87637   ['bread', 'honey mustard', 'bacon', 'butter', ...              6
# 96287   ['flour', 'salt', 'fresh ground black pepper',...             13
# 111029  ['green onions', 'gingerroot', 'crushed red pe...             13
# 115527  ['tuna', 'velveeta cheese', 'hard-boiled eggs'...              8
# 160579  ['boneless skinless chicken breasts', 'crushed...             12
# 163101  ['pork chops', 'salt', 'pepper', 'garlic powde...              9
# 169432  ['red onion', 'butter', 'pappardelle pasta', '...             10
# 169559  ['garlic-infused olive oil', 'spaghetti', 'red...              5
# 185435  ['eggs', 'medium shrimp', 'crabmeat', 'zucchin...             15
# 194375  ['butter', 'garlic cloves', 'onion', 'orange b...             10
# 215200  ['white onion', 'garlic cloves', 'dried basil'...             12
#
#         calories  total fat (PDV) sugar (PDV) sodium (PDV)  protein (PDV)  \
# 28307      329.0              8.0         5.0         12.0           82.0
# 42597      363.4             29.0         8.0         32.0           72.0
# 43342      344.4             26.0        11.0         23.0           73.0
# 77167      449.4             25.0       213.0          4.0           24.0
# 87637      334.3             27.0        20.0         25.0           24.0
# 96287      376.9             29.0        10.0         37.0           59.0
# 111029     364.4              5.0        28.0         10.0           38.0
# 115527     427.6             28.0        35.0         37.0           39.0
# 160579     426.3             27.0        85.0         52.0           58.0
# 163101     516.4             22.0         7.0        170.0           69.0
# 169432     329.8             12.0         8.0          9.0           35.0
# 169559     552.0             23.0        17.0          0.0           30.0
# 185435     330.9             29.0        18.0         31.0           58.0
# 194375     466.6             23.0        30.0         35.0           87.0
# 215200     331.2             13.0        25.0          1.0           37.0
#
#        saturated fat (PDV)  carbohydrates (PDV)
# 28307                  5.0                  9.0
# 42597                 47.0                  3.0
# 43342                 32.0                  3.0
# 77167                 39.0                 21.0
# 87637                 31.0                 10.0
# 96287                 25.0                  5.0
# 111029                11.0                 21.0
# 115527                28.0                 15.0
# 160579                41.0                 13.0
# 163101                25.0                 19.0
# 169432                20.0                 15.0
# 169559                10.0                 29.0
# 185435                20.0                  3.0
# 194375                38.0                 12.0
# 215200                22.0                 15.0
